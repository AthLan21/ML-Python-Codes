# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5]
y = [3, 7, 9, 6, 4, 5,14, 7, 6, 16, 12]

plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')

plt.show()
